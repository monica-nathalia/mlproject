# %% [markdown]
# ## Part 2

# %% [markdown]
# ##  Importing training data

# %%
#Reads and parse training data from file
import numpy as np

data_CN = open('CN/train', "r")
data_EN = open('EN/train', "r")
data_FR = open('FR/train', "r")
data_SG = open('SG/train', "r")

def cleanData(_data):
    output=[]
    l1 = "STOP STOP"
    l2 = "START START"
    output.append(tuple(l2.split(" ")))
    for l in _data:
        line = []
        if l =="\n":
            
            output.append(tuple(l1.split(" ")))
            output.append(tuple(l2.split(" ")))
        else:
            output.append(tuple(l.strip("\n").split(" ")))
    return output

trainingSet_CN = cleanData(data_CN)
trainingSet_EN = cleanData(data_EN)
trainingSet_FR = cleanData(data_FR)
trainingSet_SG = cleanData(data_SG)

# %% [markdown]
# ## Data preprocessing

# %%
#Returns dict of {words: count}
def countWords(_data):
    words = {}
    for pair in _data:
        if pair[0] in words:
            words[pair[0]] += 1
        else:
            words[pair[0]] = 1
            
    return words

#Replaces unknown words with #UNK# based on threshold k
def replaceWithUnknowns(data, k):
    words = countWords(data)
    
    output = []
    
    for pair in data:
        if words.get(pair[0])>k:
            output.append(pair)
        else:
            output.append(('#UNK#',pair[1]))
            
    return output, words

modifiedSet_CN, words_CN = replaceWithUnknowns(trainingSet_CN, 3)
modifiedSet_EN, words_EN = replaceWithUnknowns(trainingSet_EN, 3)
modifiedSet_FR, words_FR = replaceWithUnknowns(trainingSet_FR, 3)
modifiedSet_SG, words_SG = replaceWithUnknowns(trainingSet_SG, 3)
modifiedSet_EN
# Out:
# [('START', 'START'),
#  ('We', 'O'),
#  ('were', 'O'),
#  ('then', 'O'),
#  ('#UNK#', 'O'),
#  ('for', 'O'),
#  ('their', 'O'),
#  ('most', 'O'),
#  ('expensive', 'O'),
#  ('sake', 'O'),
#  ('(', 'O'),
#  ('$', 'O'),
#  ('20', 'O'),
#  ('+', 'O'),
#  ('per', 'O'),
#  ('#UNK#', 'O'),
#  (')', 'O'),
#  ('when', 'O'),
#  ('we', 'O'),
#  ('in', 'O'),
#  ('fact', 'O'),
#  ('#UNK#', 'O'),
#  ('a', 'O'),
#  ('sake', 'O'),
#  ('of', 'O'),
#  ('less', 'O'),
#  ('than', 'O'),
#  ('half', 'O'),
#  ('that', 'O'),
#  ('price', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'B-neutral'),
#  ('is', 'O'),
#  ('nothing', 'O'),
#  ('special', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Great', 'O'),
#  ('#UNK#', 'B-positive'),
#  ('and', 'O'),
#  ('worth', 'O'),
#  ('every', 'O'),
#  ('bit', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('delicious', 'O'),
#  ('bagels', 'B-positive'),
#  (',', 'O'),
#  ('especially', 'O'),
#  ('when', 'O'),
#  ('right', 'O'),
#  ('out', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Go', 'O'),
#  ('here', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Highly', 'O'),
#  ('recommended', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('But', 'O'),
#  ('who', 'O'),
#  ('says', 'O'),
#  ('#UNK#', 'O'),
#  ('is', 'O'),
#  ('anything', 'O'),
#  ('about', 'O'),
#  ('service', 'B-negative'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('atmosphere', 'O'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  ('of', 'O'),
#  ('an', 'O'),
#  ('#UNK#', 'O'),
#  ('crowd', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('there', 'O'),
#  ('were', 'O'),
#  ('a', 'O'),
#  ('few', 'O'),
#  ('#UNK#', 'O'),
#  ('of', 'O'),
#  ('mid', 'O'),
#  ('20', 'O'),
#  ("'", 'O'),
#  ('s', 'O'),
#  ('/', 'O'),
#  ('30', 'O'),
#  ('year', 'O'),
#  ('#UNK#', 'O'),
#  ('also', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Just', 'O'),
#  ('#UNK#', 'O'),
#  ('up', 'O'),
#  ('cheap', 'O'),
#  (',', 'O'),
#  ('good', 'O'),
#  ('food', 'B-positive'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('service', 'B-negative'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  (',', 'O'),
#  ('we', 'O'),
#  ('had', 'O'),
#  ('to', 'O'),
#  ('wait', 'O'),
#  ('for', 'O'),
#  ('everything', 'O'),
#  ('and', 'O'),
#  ('ask', 'O'),
#  ('several', 'O'),
#  ('of', 'O'),
#  ('different', 'O'),
#  ('people', 'O'),
#  ('for', 'O'),
#  ('the', 'O'),
#  ('same', 'O'),
#  ('thing', 'O'),
#  ('before', 'O'),
#  ('we', 'O'),
#  ('were', 'O'),
#  ('#UNK#', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('served', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('This', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('great', 'O'),
#  ('place', 'O'),
#  ('to', 'O'),
#  ('get', 'O'),
#  ('a', 'O'),
#  ('delicious', 'O'),
#  ('meal', 'B-positive'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'O'),
#  ('so', 'O'),
#  ('now', 'O'),
#  ('what', 'O'),
#  ('are', 'O'),
#  ('appetizers', 'O'),
#  ('for', 'O'),
#  ('?', 'O'),
#  ('?', 'O'),
#  ('?', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('I', 'O'),
#  ('#UNK#', 'O'),
#  ('that', 'O'),
#  ('dining', 'O'),
#  ('at', 'O'),
#  ('Casa', 'B-negative'),
#  ('La', 'I-negative'),
#  ('Femme', 'I-negative'),
#  ('is', 'O'),
#  ('like', 'O'),
#  ('no', 'O'),
#  ('other', 'O'),
#  ('dining', 'O'),
#  ('experience', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('It', 'O'),
#  ("wasn't", 'O'),
#  ('the', 'O'),
#  ('#UNK#', 'O'),
#  ('seafood', 'B-neutral'),
#  ('ever', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('the', 'O'),
#  ('taste', 'O'),
#  ('and', 'O'),
#  ('#UNK#', 'O'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('They', 'O'),
#  ('have', 'O'),
#  ('authentic', 'O'),
#  ('Indian', 'B-positive'),
#  ('at', 'O'),
#  ('#UNK#', 'O'),
#  ('prices', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('food', 'B-positive'),
#  ('was', 'O'),
#  ('delicious', 'O'),
#  ('(', 'O'),
#  ('I', 'O'),
#  ('had', 'O'),
#  ('a', 'O'),
#  ('#UNK#', 'B-positive'),
#  ('special', 'I-positive'),
#  (',', 'O'),
#  ('my', 'O'),
#  ('husband', 'O'),
#  ('had', 'O'),
#  ('steak', 'B-positive'),
#  (')', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('service', 'B-positive'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('the', 'O'),
#  ('food', 'B-neutral'),
#  ('is', 'O'),
#  ('decent', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('i', 'O'),
#  ('am', 'O'),
#  ('never', 'O'),
#  ('disappointed', 'O'),
#  ('with', 'O'),
#  ('there', 'O'),
#  ('food', 'B-positive'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('everyone', 'O'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  ('and', 'O'),
#  ('helpful', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('the', 'O'),
#  ('#UNK#', 'B-positive'),
#  ('#UNK#', 'I-positive'),
#  ('even', 'O'),
#  ('#UNK#', 'O'),
#  ('that', 'O'),
#  ('my', 'O'),
#  ('table', 'O'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  ('a', 'O'),
#  ('#UNK#', 'O'),
#  ('it', 'O'),
#  ('for', 'O'),
#  ('me', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('–', 'O'),
#  ('This', 'O'),
#  ('place', 'O'),
#  ('is', 'O'),
#  ('#UNK#', 'O'),
#  ('for', 'O'),
#  ('their', 'O'),
#  ('breakfast', 'B-positive'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('When', 'O'),
#  ('I', 'O'),
#  ('got', 'O'),
#  ('there', 'O'),
#  ('I', 'O'),
#  ('sat', 'O'),
#  ('up', 'O'),
#  ('#UNK#', 'O'),
#  ('where', 'O'),
#  ('the', 'O'),
#  ('atmosphere', 'B-positive'),
#  ('was', 'O'),
#  ('cozy', 'O'),
#  ('&', 'O'),
#  ('the', 'O'),
#  ('service', 'B-negative'),
#  ('was', 'O'),
#  ('horrible', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('It', 'O'),
#  ('is', 'O'),
#  ('#UNK#', 'O'),
#  ('far', 'O'),
#  ('from', 'O'),
#  ('the', 'O'),
#  ('small', 'O'),
#  ('street', 'O'),
#  ("it's", 'O'),
#  ('on', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('there', 'O'),
#  ('is', 'O'),
#  ('no', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('–', 'O'),
#  ('#UNK#', 'O'),
#  ('yourself', 'O'),
#  ('the', 'O'),
#  ('waste', 'O'),
#  ('of', 'O'),
#  ('time', 'O'),
#  ('&', 'O'),
#  ('#UNK#', 'O'),
#  ('NOT', 'O'),
#  ('visit', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'O'),
#  (',', 'O'),
#  ('of', 'O'),
#  ('course', 'O'),
#  (',', 'O'),
#  ('are', 'O'),
#  ('#UNK#', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Also', 'O'),
#  ('they', 'O'),
#  ('were', 'O'),
#  ('$', 'O'),
#  ('15', 'O'),
#  ('each', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  ('up', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('This', 'O'),
#  ('guy', 'O'),
#  ('#UNK#', 'O'),
#  ('to', 'O'),
#  ('seat', 'O'),
#  ('her', 'O'),
#  ('and', 'O'),
#  ('she', 'O'),
#  ('left', 'O'),
#  (',', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  ('by', 'O'),
#  ('the', 'O'),
#  ('four', 'O'),
#  ('of', 'O'),
#  ('us', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('not', 'O'),
#  ('before', 'O'),
#  ('I', 'O'),
#  ('told', 'O'),
#  ('#UNK#', 'O'),
#  ('that', 'O'),
#  ('in', 'O'),
#  ('my', 'O'),
#  ('#UNK#', 'O'),
#  ('years', 'O'),
#  ('of', 'O'),
#  ('world', 'O'),
#  ('#UNK#', 'O'),
#  (',', 'O'),
#  ('including', 'O'),
#  ('#UNK#', 'O'),
#  (',', 'O'),
#  ('that', 'O'),
#  ('I', 'O'),
#  ('had', 'O'),
#  ('never', 'O'),
#  ('seen', 'O'),
#  ('such', 'O'),
#  ('a', 'O'),
#  ('#UNK#', 'O'),
#  ('of', 'O'),
#  ('bad', 'O'),
#  ('#UNK#', 'O'),
#  ('by', 'O'),
#  ('a', 'O'),
#  ('#UNK#', 'B-negative'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('restaurant', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('I', 'O'),
#  ('really', 'O'),
#  ('liked', 'O'),
#  ('this', 'O'),
#  ('place', 'B-positive'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('filet', 'B-positive'),
#  ('#UNK#', 'I-positive'),
#  ('dish', 'I-positive'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'B-positive'),
#  ('#UNK#', 'I-positive'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('great', 'O'),
#  ('casual', 'O'),
#  ('place', 'O'),
#  ('to', 'O'),
#  ('just', 'O'),
#  ('#UNK#', 'O'),
#  ('a', 'O'),
#  ('bite', 'O'),
#  ('to', 'O'),
#  ('eat', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('I', 'O'),
#  ('have', 'O'),
#  ('never', 'O'),
#  ('been', 'O'),
#  ('so', 'O'),
#  ('#UNK#', 'O'),
#  ('by', 'O'),
#  ('both', 'O'),
#  ('food', 'B-negative'),
#  ('an', 'O'),
#  ('service', 'B-negative'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('So', 'O'),
#  (',', 'O'),
#  ('if', 'O'),
#  ("you're", 'O'),
#  ('#UNK#', 'O'),
#  ('by', 'O'),
#  ('and', 'O'),
#  ('#UNK#', 'O'),
#  ('about', 'O'),
#  ('dining', 'O'),
#  (',', 'O'),
#  ('you', 'O'),
#  ('might', 'O'),
#  ('want', 'O'),
#  ('to', 'O'),
#  ('see', 'O'),
#  ('#UNK#', 'O'),
#  ('going', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('seating', 'O'),
#  ('you', 'O'),
#  ('first', 'O'),
#  ('...', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Good', 'O'),
#  ('for', 'O'),
#  ('late', 'O'),
#  ('night', 'O'),
#  ('dining', 'O'),
#  ('(', 'O'),
#  ('last', 'O'),
#  ('#UNK#', 'O'),
#  ('planning', 'O'),
#  (')', 'O'),
#  ('without', 'O'),
#  ('reservations', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('pizza', 'B-positive'),
#  ('is', 'O'),
#  ('delicious', 'O'),
#  ('-', 'O'),
#  ('they', 'O'),
#  ('use', 'O'),
#  ('fresh', 'B-positive'),
#  ('#UNK#', 'I-positive'),
#  ('instead', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('cheap', 'O'),
#  (',', 'O'),
#  ('frozen', 'O'),
#  (',', 'O'),
#  ('#UNK#', 'O'),
#  ('cheese', 'O'),
#  ('#UNK#', 'O'),
#  ('to', 'O'),
#  ('most', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('service', 'B-positive'),
#  ('is', 'O'),
#  ('friendly', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('never', 'O'),
#  ('had', 'O'),
#  ('a', 'O'),
#  ('problem', 'O'),
#  ('#UNK#', 'O'),
#  ('in', 'O'),
#  ('and', 'O'),
#  ('getting', 'O'),
#  ('a', 'O'),
#  ('table', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('I', 'O'),
#  ("can't", 'O'),
#  ('remember', 'O'),
#  ('the', 'O'),
#  ('last', 'O'),
#  ('time', 'O'),
#  ('I', 'O'),
#  ('had', 'O'),
#  ('such', 'O'),
#  ('#UNK#', 'O'),
#  ('food', 'B-negative'),
#  ('in', 'O'),
#  ('New', 'O'),
#  ('York', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('only', 'O'),
#  ('#UNK#', 'O'),
#  ('we', 'O'),
#  ('did', 'O'),
#  ('#UNK#', 'O'),
#  ('was', 'O'),
#  ('water', 'O'),
#  ('in', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'O'),
#  ('wait', 'O'),
#  ('to', 'O'),
#  ('go', 'O'),
#  ('back', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'B-positive'),
#  ('+', 'I-positive'),
#  ('shrimp', 'I-positive'),
#  ('appetizer', 'I-positive'),
#  ('was', 'O'),
#  ('really', 'O'),
#  ('great', 'O'),
#  (',', 'O'),
#  ('we', 'O'),
#  ('both', 'O'),
#  ('had', 'O'),
#  ('the', 'O'),
#  ('filet', 'B-positive'),
#  (',', 'O'),
#  ('very', 'O'),
#  ('good', 'O'),
#  (',', 'O'),
#  ("didn't", 'O'),
#  ('much', 'O'),
#  ('like', 'O'),
#  ('the', 'O'),
#  ('#UNK#', 'B-negative'),
#  ('that', 'O'),
#  ('came', 'O'),
#  ('with', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('the', 'O'),
#  ('filet', 'O'),
#  ('was', 'O'),
#  ('so', 'O'),
#  ('good', 'O'),
#  (',', 'O'),
#  ('#UNK#', 'O'),
#  ('of', 'O'),
#  ('us', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('wine', 'B-positive'),
#  ('list', 'I-positive'),
#  ('is', 'O'),
#  ('excellent', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('I', 'O'),
#  ('had', 'O'),
#  ('Lobster', 'B-positive'),
#  ('#UNK#', 'I-positive'),
#  ('it', 'O'),
#  ('has', 'O'),
#  ('2', 'O'),
#  ('oz', 'O'),
#  ('.', 'O'),
#  ('of', 'O'),
#  ('#UNK#', 'O'),
#  ('Lobster', 'O'),
#  ('in', 'O'),
#  ('it', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('hostess', 'B-positive'),
#  ('was', 'O'),
#  ('very', 'O'),
#  ('pleasant', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('best', 'O'),
#  ('thing', 'O'),
#  ('is', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('prices', 'O'),
#  ('are', 'O'),
#  ('also', 'O'),
#  ('quite', 'O'),
#  ('reasonable', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('I', 'O'),
#  ("won't", 'O'),
#  ('go', 'O'),
#  ('back', 'O'),
#  ('#UNK#', 'O'),
#  ('someone', 'O'),
#  ('else', 'O'),
#  ('is', 'O'),
#  ('#UNK#', 'O'),
#  ('the', 'O'),
#  ('bill', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('main', 'B-positive'),
#  ('entree', 'I-positive'),
#  ('was', 'O'),
#  ('also', 'O'),
#  ('very', 'O'),
#  ('good', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Great', 'O'),
#  ('place', 'B-positive'),
#  (',', 'O'),
#  ('great', 'O'),
#  ('value', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('food', 'B-positive'),
#  ('is', 'O'),
#  ('fantastic', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('waiting', 'B-positive'),
#  ('staff', 'I-positive'),
#  ('has', 'O'),
#  ('been', 'O'),
#  ('perfect', 'O'),
#  ('every', 'O'),
#  ('#UNK#', 'O'),
#  ('time', 'O'),
#  ("we've", 'O'),
#  ('been', 'O'),
#  ('there', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'O'),
#  ('times', 'O'),
#  ('I', 'O'),
#  ('was', 'O'),
#  ('extremely', 'O'),
#  ('#UNK#', 'O'),
#  ('by', 'O'),
#  ('the', 'O'),
#  ('service', 'B-negative'),
#  (',', 'O'),
#  ('which', 'O'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  ('rude', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Just', 'O'),
#  ('went', 'O'),
#  ('here', 'O'),
#  ('for', 'O'),
#  ('my', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('I', 'O'),
#  ('am', 'O'),
#  ('going', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('mid', 'O'),
#  ('town', 'O'),
#  ('location', 'O'),
#  ('next', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('delicious', 'O'),
#  ('simple', 'O'),
#  ('food', 'B-positive'),
#  ('in', 'O'),
#  ('nice', 'O'),
#  ('outdoor', 'B-positive'),
#  ('atmosphere', 'I-positive'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'O'),
#  ('than', 'O'),
#  ('three', 'O'),
#  ('minutes', 'O'),
#  ('#UNK#', 'O'),
#  ('before', 'O'),
#  ('I', 'O'),
#  ('found', 'O'),
#  ('myself', 'O'),
#  ('#UNK#', 'O'),
#  ('over', 'O'),
#  ('the', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('#UNK#', 'B-positive'),
#  ('for', 'I-positive'),
#  ('brunch', 'I-positive'),
#  ('is', 'O'),
#  ('great', 'O'),
#  ('...', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('#UNK#', 'O'),
#  ('of', 'O'),
#  ('#UNK#', 'O'),
#  ('was', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ("I'm", 'O'),
#  ('still', 'O'),
#  ('#UNK#', 'O'),
#  ('that', 'O'),
#  ('i', 'O'),
#  ('had', 'O'),
#  ('to', 'O'),
#  ('pay', 'O'),
#  ('for', 'O'),
#  ('#UNK#', 'O'),
#  ('food', 'B-negative'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Love', 'O'),
#  ('the', 'O'),
#  ('#UNK#', 'B-positive'),
#  ('first', 'O'),
#  ('off', 'O'),
#  ('-', 'O'),
#  ('the', 'O'),
#  ('place', 'B-positive'),
#  ('has', 'O'),
#  ('a', 'O'),
#  ('#UNK#', 'O'),
#  ('and', 'O'),
#  ('nice', 'O'),
#  ('#UNK#', 'O'),
#  ('to', 'O'),
#  ('it', 'O'),
#  ('..', 'O'),
#  ('very', 'O'),
#  ('#UNK#', 'O'),
#  (',', 'O'),
#  ('location', 'B-positive'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('atmosphere', 'B-negative'),
#  ('was', 'O'),
#  ('pretty', 'O'),
#  ('nice', 'O'),
#  ('but', 'O'),
#  ('had', 'O'),
#  ('a', 'O'),
#  ('bit', 'O'),
#  ('lacking', 'O'),
#  (',', 'O'),
#  ('which', 'O'),
#  ('it', 'O'),
#  ('#UNK#', 'O'),
#  ('to', 'O'),
#  ('make', 'O'),
#  ('up', 'O'),
#  ('for', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'B-negative'),
#  ('of', 'I-negative'),
#  ('#UNK#', 'I-negative'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('#UNK#', 'B-positive'),
#  ('#UNK#', 'I-positive'),
#  ('#UNK#', 'I-positive'),
#  ('on', 'O'),
#  ('Saturday', 'O'),
#  ('nights', 'O'),
#  ('has', 'O'),
#  ('#UNK#', 'O'),
#  ('good', 'O'),
#  ('taste', 'O'),
#  ('in', 'O'),
#  ('music', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('#UNK#', 'O'),
#  (',', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('A', 'O'),
#  ('pleasant', 'O'),
#  ('#UNK#', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('The', 'O'),
#  ('food', 'O'),
#  ('arrived', 'O'),
#  ('in', 'O'),
#  ('about', 'O'),
#  ('15', 'O'),
#  ('minutes', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('Their', 'O'),
#  ('sake', 'B-positive'),
#  ('list', 'I-positive'),
#  ('was', 'O'),
#  ('extensive', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('we', 'O'),
#  ('were', 'O'),
#  ('looking', 'O'),
#  ('for', 'O'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'O'),
#  (',', 'O'),
#  ('which', 'O'),
#  ("wasn't", 'O'),
#  ('listed', 'O'),
#  ('but', 'O'),
#  ('made', 'O'),
#  ('for', 'O'),
#  ('us', 'O'),
#  ('upon', 'O'),
#  ('#UNK#', 'O'),
#  ('!', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('i', 'O'),
#  ("don't", 'O'),
#  ('usually', 'O'),
#  ('order', 'O'),
#  ('wine', 'O'),
#  ('with', 'O'),
#  ('indian', 'O'),
#  ('so', 'O'),
#  ('i', 'O'),
#  ("can't", 'O'),
#  ('comment', 'O'),
#  ('on', 'O'),
#  ('their', 'O'),
#  ('wine', 'O'),
#  ('list', 'O'),
#  ('or', 'O'),
#  ('their', 'O'),
#  ('wines', 'O'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('#UNK#', 'O'),
#  ('#UNK#', 'B-positive'),
#  ('food', 'I-positive'),
#  ('.', 'O'),
#  ('STOP', 'STOP'),
#  ('START', 'START'),
#  ('All', 'O'),
#  ('in', 'O'),
#  ('all', 'O'),
#  (',', 'O'),
#  ('this', 'O'),
#  ('#UNK#', 'O'),
#  ('gem', 'O'),
#  ('#UNK#', 'O'),
#  ...]

# %% [markdown]
# ## Estimation of emission parameters

# %%
def countWordTagPairs(_data):
    tags = {}
    tag_emits_word = {}

    for pair in _data:
        if pair[1] in tags:
            tags[pair[1]] += 1
        else:
            tags[pair[1]] = 1

        if pair in tag_emits_word:
            tag_emits_word[pair] +=1
        else:
            tag_emits_word[pair] =1
            
    return tags, tag_emits_word
    
def estimateEmissionParams(_data):
    output={}
    
    tags, tag_emits_word = countWordTagPairs(_data)
    
    for pair in tag_emits_word:
        if pair not in output:
            output[pair] = tag_emits_word.get(pair)/ tags.get(pair[1])
            
    return output,tags
                
emissionParams_CN, tags_CN = estimateEmissionParams(modifiedSet_CN)
emissionParams_EN, tags_EN = estimateEmissionParams(modifiedSet_EN)
emissionParams_FR, tags_FR = estimateEmissionParams(modifiedSet_FR)
emissionParams_SG, tags_SG = estimateEmissionParams(modifiedSet_SG)

emissionParams_EN
# Out:
# {('START', 'START'): 1.0,
#  ('We', 'O'): 0.0034238099166735416,
#  ('were', 'O'): 0.005156340235954129,
#  ('then', 'O'): 0.0006187608283144955,
#  ('#UNK#', 'O'): 0.14219123834667108,
#  ('for', 'O'): 0.011508951406649617,
#  ('their', 'O'): 0.0021450375381569177,
#  ('most', 'O'): 0.0010725187690784589,
#  ('expensive', 'O'): 0.0005362593845392294,
#  ('sake', 'O'): 0.0002475043313257982,
#  ('(', 'O'): 0.003300057751010643,
#  ('$', 'O'): 0.0018975332068311196,
#  ('20', 'O'): 0.0002475043313257982,
#  ('+', 'O'): 0.00016500288755053212,
#  ('per', 'O'): 0.00020625360943816518,
#  (')', 'O'): 0.0034238099166735416,
#  ('when', 'O'): 0.0016912795973929543,
#  ('we', 'O'): 0.005486346011055194,
#  ('in', 'O'): 0.010560184803234056,
#  ('fact', 'O'): 0.0003712564969886973,
#  ('without', 'O'): 0.0005775101064268625,
#  ('reservations', 'O'): 0.00016500288755053212,
#  ('pizza', 'B-positive'): 0.0173841059602649,
#  ('-', 'O'): 0.0035063113604488078,
#  ('use', 'O'): 0.00020625360943816518,
#  ('fresh', 'B-positive'): 0.0016556291390728477,
#  ('instead', 'O'): 0.0002475043313257982,
#  ('frozen', 'O'): 0.0001237521656628991,
#  ('cheese', 'O'): 0.0002475043313257982,
#  ('friendly', 'O'): 0.001196270934741358,
#  ('problem', 'O'): 0.00028875505321343124,
#  ('getting', 'O'): 0.00033000577510106425,
#  ("can't", 'O'): 0.001237521656628991,
#  ('remember', 'O'): 0.00033000577510106425,
#  ('New', 'O'): 0.0005775101064268625,
#  ('York', 'O'): 0.00045375794076396337,
#  ('only', 'O'): 0.0016087781536176884,
#  ('did', 'O'): 0.0008662651596402937,
#  ('water', 'O'): 0.00033000577510106425,
#  ('go', 'O'): 0.003217556307235377,
#  ('back', 'O'): 0.002681296922696147,
#  ('+', 'I-positive'): 0.0016474464579901153,
#  ('shrimp', 'I-positive'): 0.006589785831960461,
#  ('appetizer', 'I-positive'): 0.006589785831960461,
#  ('very', 'O'): 0.004248824354426203,
#  ("didn't", 'O'): 0.0008250144377526607,
#  ('much', 'O'): 0.0010725187690784589,
#  ('came', 'O'): 0.001155020212853725,
#  ('filet', 'O'): 4.125072188763303e-05,
#  ('wine', 'B-positive'): 0.015728476821192054,
#  ('list', 'I-positive'): 0.0214168039538715,
#  ('excellent', 'O'): 0.001113769490966092,
#  ('Lobster', 'B-positive'): 0.0016556291390728477,
#  ('has', 'O'): 0.0014437752660671562,
#  ('2', 'O'): 0.0006600115502021285,
#  ('oz', 'O'): 0.0001237521656628991,
#  ('Lobster', 'O'): 8.250144377526606e-05,
#  ('hostess', 'B-positive'): 0.0008278145695364238,
#  ('pleasant', 'O'): 0.00028875505321343124,
#  ('best', 'O'): 0.0025575447570332483,
#  ('quite', 'O'): 0.0004950086626515964,
#  ('reasonable', 'O'): 0.0003712564969886973,
#  ("won't", 'O'): 0.00028875505321343124,
#  ('someone', 'O'): 0.0002475043313257982,
#  ('else', 'O'): 0.00041250721887633036,
#  ('bill', 'O'): 0.0004950086626515964,
#  ('main', 'B-positive'): 0.0024834437086092716,
#  ('entree', 'I-positive'): 0.0032948929159802307,
#  ('value', 'O'): 0.00028875505321343124,
#  ('fantastic', 'O'): 0.0004950086626515964,
#  ('waiting', 'B-positive'): 0.0008278145695364238,
#  ('staff', 'I-positive'): 0.006589785831960461,
#  ('perfect', 'O'): 0.0006187608283144955,
#  ("we've", 'O'): 0.0003712564969886973,
#  ('times', 'O'): 0.0009900173253031927,
#  ('extremely', 'O'): 0.0003712564969886973,
#  ('which', 'O'): 0.002640046200808514,
#  ('rude', 'O'): 0.0006187608283144955,
#  ('went', 'O'): 0.001113769490966092,
#  ('town', 'O'): 0.0004950086626515964,
#  ('location', 'O'): 0.00016500288755053212,
#  ('next', 'O'): 0.0006187608283144955,
#  ('simple', 'O'): 0.00016500288755053212,
#  ('Green', 'O'): 8.250144377526606e-05,
#  ('likely', 'O'): 0.00016500288755053212,
#  ('private', 'B-positive'): 0.0008278145695364238,
#  ('glass', 'B-positive'): 0.0016556291390728477,
#  ('pizza', 'B-negative'): 0.010471204188481676,
#  ('cheese', 'B-negative'): 0.002617801047120419,
#  ('interesting', 'O'): 0.00020625360943816518,
#  ('long', 'O'): 0.00033000577510106425,
#  ('bathroom', 'O'): 8.250144377526606e-05,
#  (':)', 'O'): 0.0002475043313257982,
#  ('area', 'O'): 0.0003712564969886973,
#  ('Thai', 'B-positive'): 0.0033112582781456954,
#  ('fabulous', 'O'): 0.00016500288755053212,
#  ('dessert', 'B-positive'): 0.0016556291390728477,
#  ('week', 'O'): 0.00028875505321343124,
#  ('decor', 'I-positive'): 0.0032948929159802307,
#  ('white', 'B-positive'): 0.0016556291390728477,
#  ('tuna', 'O'): 8.250144377526606e-05,
#  ("Ray's", 'O'): 0.00016500288755053212,
#  ('scallops', 'O'): 4.125072188763303e-05,
#  ('crab', 'O'): 4.125072188763303e-05,
#  ('sauce', 'I-positive'): 0.004942339373970346,
#  ('Drinks', 'B-positive'): 0.0016556291390728477,
#  ('however', 'O'): 0.0003712564969886973,
#  ('(', 'I-positive'): 0.009884678747940691,
#  (')', 'I-positive'): 0.009884678747940691,
#  ('Mioposto', 'O'): 4.125072188763303e-05,
#  ('server', 'B-positive'): 0.0041390728476821195,
#  ("Ray's", 'B-neutral'): 0.015384615384615385,
#  ('young', 'O'): 0.0001237521656628991,
#  ('dinner', 'B-negative'): 0.005235602094240838,
#  ('he', 'O'): 0.0005362593845392294,
#  ('notch', 'O'): 0.00016500288755053212,
#  ('walk', 'O'): 0.00016500288755053212,
#  ('sitting', 'O'): 0.00028875505321343124,
#  ('except', 'O'): 0.00016500288755053212,
#  ('6', 'O'): 0.00016500288755053212,
#  ('bathroom', 'B-negative'): 0.005235602094240838,
#  ('cold', 'B-positive'): 0.0008278145695364238,
#  ('share', 'O'): 0.0002475043313257982,
#  ('delivery', 'O'): 8.250144377526606e-05,
#  ('drinks', 'B-negative'): 0.005235602094240838,
#  ('desserts', 'B-positive'): 0.0008278145695364238,
#  ('appetizer', 'B-positive'): 0.0033112582781456954,
#  ('beer', 'O'): 8.250144377526606e-05,
#  ('Japanese', 'I-positive'): 0.0032948929159802307,
#  ('spot', 'O'): 0.00016500288755053212,
#  ('sauce', 'O'): 0.0001237521656628991,
#  ('prawns', 'B-positive'): 0.0008278145695364238,
#  ('tempura', 'I-positive'): 0.004942339373970346,
#  ('by', 'I-positive'): 0.0016474464579901153,
#  ...}

# %% [markdown]
# ## Simple sentiment prediction

# %%
#Predicts sentiment (state) from words (observation) based on MLE from training data
def predictSentiment(_word, _params, _tags, _words, _outputFile):
    maximumLikelihood = 0
    sentiment = 'O'
    
    if _word in _words:
        for tag in _tags:
            likelihood = _params.get((_word,tag))

            if likelihood == None:
                pass
            
            else:
                if likelihood>maximumLikelihood:
                    maximumLikelihood = likelihood
                    sentiment = tag
    else:
        pass
    
    _outputFile.write(_word+' '+sentiment+'\n')
    
    
#Cleans input corpus and trims tailing whitespaces        
def cleanTestData(_data):
    output = []
    for l in _data:
        output.append(l.strip("\n"))
    return output

#Predicts sentiment of input corpus and writes to output file
def simpleSentimentPrediction(_inputFile, _outputFile, _emissionParams, _tags, _words):
    test_data = open(_inputFile, "r")
    predicted_data = open(_outputFile, "w")
    
    cleaned = cleanTestData(test_data)
  
    for word in cleaned:
        if word == '':
            predicted_data.write('\n')
        else:
            predictSentiment(word, _emissionParams, _tags, _words, predicted_data)
    
simpleSentimentPrediction('CN/dev.in', 'CN/dev.p2.out', emissionParams_CN, tags_CN, words_CN)
simpleSentimentPrediction('EN/dev.in', 'EN/dev.p2.out', emissionParams_EN, tags_EN, words_EN)
simpleSentimentPrediction('FR/dev.in', 'FR/dev.p2.out', emissionParams_FR, tags_FR, words_FR)
simpleSentimentPrediction('SG/dev.in', 'SG/dev.p2.out', emissionParams_SG, tags_SG, words_SG)

# %% [markdown]
# # Part 3

# %% [markdown]
# ## Estimation of Transition Parameters

# %%
def TagTagTransitionPairs(_data):
    arrayofTransitionPairs =[]
    for i in range(len(_data)):
        arrayofTransitionPairs.append((_data[i-1][1],_data[i][1]))
    return arrayofTransitionPairs

def countTagTagPairs(_arrayofTransitionPairs):
    tagtag = {}
    for pair in _arrayofTransitionPairs:
        if pair in tagtag:
            tagtag[pair] +=1
        else:
            tagtag[pair] =1
    return tagtag

tagtagpairs_CN = TagTagTransitionPairs(modifiedSet_CN)
tagtag_CN = countTagTagPairs(tagtagpairs_CN)
tagtagpairs_EN = TagTagTransitionPairs(modifiedSet_EN)
tagtag_EN = countTagTagPairs(tagtagpairs_EN)
tagtagpairs_FR = TagTagTransitionPairs(modifiedSet_FR)
tagtag_FR = countTagTagPairs(tagtagpairs_FR)
tagtagpairs_SG = TagTagTransitionPairs(modifiedSet_SG)
tagtag_SG = countTagTagPairs(tagtagpairs_SG)
tagtag_EN
# Out:
# {('B-negative', 'I-negative'): 80,
#  ('B-negative', 'O'): 299,
#  ('B-negative', 'STOP'): 3,
#  ('B-neutral', 'I-neutral'): 13,
#  ('B-neutral', 'O'): 51,
#  ('B-neutral', 'STOP'): 1,
#  ('B-positive', 'I-positive'): 360,
#  ('B-positive', 'O'): 832,
#  ('B-positive', 'STOP'): 16,
#  ('I-negative', 'I-negative'): 53,
#  ('I-negative', 'O'): 80,
#  ('I-neutral', 'I-neutral'): 10,
#  ('I-neutral', 'O'): 13,
#  ('I-positive', 'I-positive'): 247,
#  ('I-positive', 'O'): 355,
#  ('I-positive', 'STOP'): 5,
#  ('O', 'B-negative'): 362,
#  ('O', 'B-neutral'): 55,
#  ('O', 'B-positive'): 1126,
#  ('O', 'O'): 20851,
#  ('O', 'STOP'): 1848,
#  ('START', 'B-negative'): 20,
#  ('START', 'B-neutral'): 10,
#  ('START', 'B-positive'): 82,
#  ('START', 'O'): 1761,
#  ('START', 'START'): 1,
#  ('STOP', 'START'): 1873}

# %%
def estimateTransitionParams(_tagtagCounts):
    output={}
    totals = {}
    
    for k,v in _tagtagCounts.items():
        if k[0] not in totals:
            totals[k[0]] = v
        else:
            totals[k[0]] += v
            
    for tagpairs in _tagtagCounts:
        if tagpairs not in output:
            output[tagpairs] = _tagtagCounts[tagpairs]/totals[tagpairs[0]]
            
    return output

transitionParams_CN= estimateTransitionParams(tagtag_CN)
transitionParams_EN= estimateTransitionParams(tagtag_EN)
transitionParams_FR= estimateTransitionParams(tagtag_FR)
transitionParams_SG= estimateTransitionParams(tagtag_SG)
transitionParams_EN
# Out:
# {('B-negative', 'I-negative'): 0.2094240837696335,
#  ('B-negative', 'O'): 0.7827225130890052,
#  ('B-negative', 'STOP'): 0.007853403141361256,
#  ('B-neutral', 'I-neutral'): 0.2,
#  ('B-neutral', 'O'): 0.7846153846153846,
#  ('B-neutral', 'STOP'): 0.015384615384615385,
#  ('B-positive', 'I-positive'): 0.2980132450331126,
#  ('B-positive', 'O'): 0.6887417218543046,
#  ('B-positive', 'STOP'): 0.013245033112582781,
#  ('I-negative', 'I-negative'): 0.39849624060150374,
#  ('I-negative', 'O'): 0.6015037593984962,
#  ('I-neutral', 'I-neutral'): 0.43478260869565216,
#  ('I-neutral', 'O'): 0.5652173913043478,
#  ('I-positive', 'I-positive'): 0.40691927512355847,
#  ('I-positive', 'O'): 0.5848434925864909,
#  ('I-positive', 'STOP'): 0.008237232289950576,
#  ('O', 'B-negative'): 0.014932761323323157,
#  ('O', 'B-neutral'): 0.002268789703819817,
#  ('O', 'B-positive'): 0.04644831284547479,
#  ('O', 'O'): 0.8601188020790363,
#  ('O', 'STOP'): 0.07623133404834585,
#  ('START', 'B-negative'): 0.010672358591248666,
#  ('START', 'B-neutral'): 0.005336179295624333,
#  ('START', 'B-positive'): 0.04375667022411953,
#  ('START', 'O'): 0.9397011739594451,
#  ('START', 'START'): 0.0005336179295624333,
#  ('STOP', 'START'): 1.0}

# %% [markdown]
# ## Viterbi Algorithm

# %%
def ViterbiAlgorithm(_inputfile,_outputfile,_emissionParams,_transitionParams):
    test_data = open(_inputfile, "r")
    predicted_data = open(_outputfile, "w")
    
    cleaned = cleanTestData(test_data)
    processed = textToLists(cleaned)
    stored_values = {'prevProbability':1, 'prevTag': None}
    
    known_tags = []
    for k,v in _transitionParams.items():
        if k[0] not in known_tags:
            known_tags.append(k[0])

    for sentence in processed:        
        for i in range(len(sentence)):              
            if i == 0:
                stop_checker = False
                stored_values = {'prevProbability':1, 'prevTag': 'START'} #reset probability
                
            elif i == len(sentence)-1:
                stop_checker = True             
                
            else:
                stop_checker = False
                
            maxProb, currentTag = maxProbabilityWithStop(_emissionParams, _transitionParams, stored_values["prevProbability"], stored_values["prevTag"],sentence[i], known_tags, stop_checker)
            predicted_data.write(sentence[i]+' '+currentTag+'\n')
            if stop_checker == True:
                predicted_data.write('\n')#add linespace between sentences
            stored_values['prevProbability'] = maxProb
            stored_values['prevTag'] = currentTag
        
        
def maxProbabilityWithStop(_emissionParams, _transitionParams, _prevProbability, _prevTag, _currentWord, known_tags, _stop_checker):
    #Check if word is known by filtering emission params
    known_words = {k: v for k, v in _emissionParams.items() if k[0] == _currentWord}          
    probabilities=[]
    
    #If word is known
    if bool(known_words):
        pass
    #If not known, treat word as '#UNK#'
    else:
        known_words = {k: v for k, v in _emissionParams.items() if k[0] == '#UNK#'}
    
    #find max combination of emission and transition parameters
    for tag in known_tags:
        if _stop_checker == False:
            try:
                ab_val = known_words[(_currentWord,tag)]*_transitionParams[(_prevTag,tag)]

            except: 
                ab_val = 0
        #if the next tag is "stop"
        else:
            try:
                ab_val = known_words[(_currentWord,tag)]*_transitionParams[(_prevTag,tag)]*_transitionParams[(tag,'STOP')]

            except: 
                ab_val = 0
        probabilities.append((ab_val,tag))
    
    probabilities = [x for x in probabilities if x[1] != 'START'and x[1]!='STOP']
    max_abval, currentTag = max(probabilities,key=lambda item:item[0])
    currentProbability = max_abval*_prevProbability      
    return currentProbability, currentTag

def textToLists(_data): #_data is a huge list of words with '' in between sentences
    output=[]
    sentence = []
    
    for l in _data:      
        if l =='':   
            output.append(sentence)
            sentence = []
            
        else:
            sentence.append(l.strip())
    #return list of lists        
    return output

ViterbiAlgorithm('EN/dev.in','EN/dev.p3.out',emissionParams_EN,transitionParams_EN)

# %%
transitionParams_EN
# Out:
# {('B-negative', 'I-negative'): 0.2094240837696335,
#  ('B-negative', 'O'): 0.7827225130890052,
#  ('B-negative', 'STOP'): 0.007853403141361256,
#  ('B-neutral', 'I-neutral'): 0.2,
#  ('B-neutral', 'O'): 0.7846153846153846,
#  ('B-neutral', 'STOP'): 0.015384615384615385,
#  ('B-positive', 'I-positive'): 0.2980132450331126,
#  ('B-positive', 'O'): 0.6887417218543046,
#  ('B-positive', 'STOP'): 0.013245033112582781,
#  ('I-negative', 'I-negative'): 0.39849624060150374,
#  ('I-negative', 'O'): 0.6015037593984962,
#  ('I-neutral', 'I-neutral'): 0.43478260869565216,
#  ('I-neutral', 'O'): 0.5652173913043478,
#  ('I-positive', 'I-positive'): 0.40691927512355847,
#  ('I-positive', 'O'): 0.5848434925864909,
#  ('I-positive', 'STOP'): 0.008237232289950576,
#  ('O', 'B-negative'): 0.014932761323323157,
#  ('O', 'B-neutral'): 0.002268789703819817,
#  ('O', 'B-positive'): 0.04644831284547479,
#  ('O', 'O'): 0.8601188020790363,
#  ('O', 'STOP'): 0.07623133404834585,
#  ('START', 'B-negative'): 0.010672358591248666,
#  ('START', 'B-neutral'): 0.005336179295624333,
#  ('START', 'B-positive'): 0.04375667022411953,
#  ('START', 'O'): 0.9397011739594451,
#  ('START', 'START'): 0.0005336179295624333,
#  ('STOP', 'START'): 1.0}

# %%
def cleanTransitionParameters (parameters):
    seen = []
    clean_params={}
    for i in parameters:
        if i not in seen:
            clean_params.setdefault(i[0], {})
            clean_params[i[0]].update({i[1]:parameters[i]})
            seen.append(i)
    return clean_params

def cleanEmissionParameters (parameters):
    seen = []
    clean_params={}
    for i in parameters:
        if i not in seen:
            clean_params.setdefault(i[1], {})
            clean_params[i[1]].update({i[0]:parameters[i]})
            seen.append(i)
    return clean_params

emissionProb = cleanEmissionParameters(emissionParams_EN)
transitionProb = cleanTransitionParameters(transitionParams_EN)

states={'B-negative','B-neutral','B-positive','I-negative','I-neutral','I-positive','O'}
# Out:
# {'B-negative': {'"': 0.002617801047120419,
#   '#UNK#': 0.22774869109947643,
#   'Casa': 0.005235602094240838,
#   'Delivery': 0.005235602094240838,
#   'Drinks': 0.002617801047120419,
#   'Go': 0.002617801047120419,
#   'Japanese': 0.005235602094240838,
#   'Korean': 0.002617801047120419,
#   'Mioposto': 0.002617801047120419,
#   'PLACE': 0.002617801047120419,
#   'Pizza': 0.002617801047120419,
#   'Service': 0.020942408376963352,
#   'Thai': 0.007853403141361256,
#   'The': 0.005235602094240838,
#   'ambience': 0.005235602094240838,
#   'appetizer': 0.002617801047120419,
#   'atmosphere': 0.002617801047120419,
#   'bagel': 0.002617801047120419,
#   'bagels': 0.002617801047120419,
#   'bar': 0.002617801047120419,
#   'bartender': 0.005235602094240838,
#   'bathroom': 0.005235602094240838,
#   'beef': 0.002617801047120419,
#   'beer': 0.002617801047120419,
#   'breakfast': 0.002617801047120419,
#   'cheese': 0.002617801047120419,
#   'chef': 0.005235602094240838,
#   'chicken': 0.005235602094240838,
#   'customer': 0.010471204188481676,
#   'decor': 0.002617801047120419,
#   'delivery': 0.002617801047120419,
#   'dessert': 0.013089005235602094,
#   'dinner': 0.005235602094240838,
#   'dish': 0.005235602094240838,
#   'dishes': 0.010471204188481676,
#   'drinks': 0.005235602094240838,
#   'eggs': 0.002617801047120419,
#   'fish': 0.015706806282722512,
#   'food': 0.10732984293193717,
#   'front': 0.005235602094240838,
#   'goat': 0.002617801047120419,
#   'hostess': 0.005235602094240838,
#   'juice': 0.002617801047120419,
#   'manager': 0.020942408376963352,
#   'margaritas': 0.002617801047120419,
#   'meal': 0.010471204188481676,
#   'meals': 0.007853403141361256,
#   'menu': 0.010471204188481676,
#   'mushroom': 0.002617801047120419,
#   'owner': 0.002617801047120419,
#   'owners': 0.002617801047120419,
#   'pancakes': 0.002617801047120419,
#   'pasta': 0.002617801047120419,
#   'people': 0.002617801047120419,
#   'pizza': 0.010471204188481676,
#   'place': 0.06282722513089005,
#   'plate': 0.002617801047120419,
#   'pork': 0.005235602094240838,
#   'portions': 0.007853403141361256,
#   'restaurant': 0.031413612565445025,
#   'rice': 0.005235602094240838,
#   'rolls': 0.005235602094240838,
#   'room': 0.002617801047120419,
#   'salmon': 0.005235602094240838,
#   'sashimi': 0.002617801047120419,
#   'sauce': 0.002617801047120419,
#   'seafood': 0.002617801047120419,
#   'seating': 0.002617801047120419,
#   'server': 0.005235602094240838,
#   'servers': 0.005235602094240838,
#   'service': 0.09424083769633508,
#   'sitting': 0.002617801047120419,
#   'space': 0.005235602094240838,
#   'spinach': 0.005235602094240838,
#   'staff': 0.034031413612565446,
#   'steak': 0.002617801047120419,
#   'style': 8.250144377526606e-05,
#   'such': 0.0007837637158650277,
#   'sure': 0.0007837637158650277,
#   'surprised': 0.00020625360943816518,
#   'sushi': 0.0006187608283144955,
#   'sweet': 0.0002475043313257982,
#   't': 0.00033000577510106425,
#   'table': 0.00136127382229189,
#   'tables': 0.0001237521656628991,
#   'take': 0.0006187608283144955,
#   'taste': 0.0004950086626515964,
#   'tasted': 0.0005775101064268625,
#   'tasty': 0.0009487666034155598,
#   'tea': 4.125072188763303e-05,
#   'tell': 0.00020625360943816518,
#   'tempura': 4.125072188763303e-05,
#   'terrific': 0.00016500288755053212,
#   'than': 0.0015675274317300553,
#   'that': 0.007383879217886313,
#   "that's": 0.00045375794076396337,
#   'the': 0.04541704479828397,
#   'their': 0.0021450375381569177,
#   'them': 0.0006187608283144955,
#   'then': 0.0006187608283144955,
#   'there': 0.003918818579325138,
#   "there's": 0.00016500288755053212,
#   'these': 0.00028875505321343124,
#   'they': 0.0033825591947859086,
#   'thin': 0.00020625360943816518,
#   'thing': 0.0007837637158650277,
#   'things': 0.00033000577510106425,
#   'think': 0.0005362593845392294,
#   'this': 0.005857602508043891,
#   'those': 0.00033000577510106425,
#   'though': 0.0009075158815279267,
#   'thought': 0.0005362593845392294,
#   'three': 0.0002475043313257982,
#   'through': 0.0003712564969886973,
#   'time': 0.002640046200808514,
#   'times': 0.0009900173253031927,
#   'tiny': 0.0002475043313257982,
#   'tip': 0.00020625360943816518,
#   'to': 0.019676594340400956,
#   'together': 0.00020625360943816518,
#   'told': 0.00033000577510106425,
#   'too': 0.0021037868162692847,
#   'took': 0.0007012622720897616,
#   'top': 0.0007012622720897616,
#   'toppings': 8.250144377526606e-05,
#   'totally': 0.00016500288755053212,
#   'town': 0.0004950086626515964,
#   'traditional': 0.00016500288755053212,
#   'tried': 0.0004950086626515964,
#   'trip': 0.00041250721887633036,
#   'try': 0.001155020212853725,
#   'trying': 0.0003712564969886973,
#   'tuna': 8.250144377526606e-05,
#   'twice': 0.00016500288755053212,
#   'two': 0.0005775101064268625,
#   'unique': 0.00016500288755053212,
#   'up': 0.0014850259879547892,
#   'upon': 0.00020625360943816518,
#   'us': 0.0016087781536176884,
#   'use': 0.00020625360943816518,
#   'used': 0.00020625360943816518,
#   'usually': 0.00028875505321343124,
#   'value': 0.00028875505321343124,
#   'variety': 0.0002475043313257982,
#   'very': 0.004248824354426203,
#   'village': 0.00016500288755053212,
#   'visit': 0.0007837637158650277,
#   'visited': 0.00020625360943816518,
#   'wait': 0.0012787723785166241,
#   'waited': 0.00033000577510106425,
#   'waiter': 8.250144377526606e-05,
#   'waiters': 4.125072188763303e-05,
#   'waiting': 0.0003712564969886973,
#   'waitress': 0.00016500288755053212,
#   'walk': 0.00016500288755053212,
#   'walked': 0.0003712564969886973,
#   'want': 0.0008250144377526607,
#   'wanted': 0.00041250721887633036,
#   'warm': 0.0005362593845392294,
#   'was': 0.017490306080356406,
#   "wasn't": 0.0006187608283144955,
#   'waste': 0.00020625360943816518,
#   'water': 0.00033000577510106425,
#   'way': 0.0008662651596402937,
#   'we': 0.005486346011055194,
#   "we've": 0.0003712564969886973,
#   'weather': 0.00016500288755053212,
#   'week': 0.00028875505321343124,
#   'weekends': 0.00020625360943816518,
#   'well': 0.001402524544179523,
#   'went': 0.001113769490966092,
#   'were': 0.005156340235954129,
#   "weren't": 0.00016500288755053212,
#   'west': 0.00016500288755053212,
#   'what': 0.0015262767098424223,
#   'when': 0.0016912795973929543,
#   'where': 0.00041250721887633036,
#   'which': 0.002640046200808514,
#   'while': 0.0006187608283144955,
#   'white': 8.250144377526606e-05,
#   'who': 0.0009487666034155598,
#   'wife': 0.0004950086626515964,
#   'will': 0.0015675274317300553,
#   'wine': 0.00041250721887633036,
#   'wines': 4.125072188763303e-05,
#   'wish': 0.00016500288755053212,
#   'with': 0.005362593845392294,
#   'without': 0.0005775101064268625,
#   "won't": 0.00028875505321343124,
#   'wonderful': 0.0006187608283144955,
#   'work': 0.00033000577510106425,
#   'world': 0.0005362593845392294,
#   'worst': 0.00033000577510106425,
#   'worth': 0.0012787723785166241,
#   'would': 0.002268789703819817,
#   "wouldn't": 0.00020625360943816518,
#   'wrong': 0.0003712564969886973,
#   'year': 0.0002475043313257982,
#   'years': 0.0007425129939773946,
#   'yes': 0.00016500288755053212,
#   'yet': 0.00033000577510106425,
#   'you': 0.007425129939773946,
#   "you're": 0.0006187608283144955,
#   'young': 0.0001237521656628991,
#   'your': 0.0021037868162692847,
#   'yourself': 0.00033000577510106425,
#   'yummy': 0.00020625360943816518,
#   '–': 0.002392541869482716,
#   '’': 0.0005775101064268625},
#  'START': {'START': 1.0},
#  'STOP': {'STOP': 1.0}}

# %%
#Forward backward algorithm
def forward_backward ( observations, states,
                      transitionProb, emissionProb, endState):
    forward= []
    previous = {}


def fwd_bkw(observations, states, start_prob, trans_prob, emm_prob, end_st):
    # forward part of the algorithm
    fwd = []
    f_prev = {}
    for i, observation_i in enumerate(observations):
        f_curr = {}
        for st in states:
            if i == 0:
                # base case for the forward part
                prev_f_sum = start_prob[st]
            else:
                prev_f_sum = sum(f_prev[k]*trans_prob[k][st] for k in states)

            f_curr[st] = emm_prob[st][observation_i] * prev_f_sum

        fwd.append(f_curr)
        f_prev = f_curr

    p_fwd = sum(f_curr[k] * trans_prob[k][end_st] for k in states)

    # backward part of the algorithm
    bkw = []
    b_prev = {}
    for i, observation_i_plus in enumerate(reversed(observations[1:]+(None,))):
        b_curr = {}
        for st in states:
            if i == 0:
                # base case for backward part
                b_curr[st] = trans_prob[st][end_st]
            else:
                b_curr[st] = sum(trans_prob[st][l] * emm_prob[l][observation_i_plus] * b_prev[l] for l in states)

        bkw.insert(0,b_curr)
        b_prev = b_curr

    p_bkw = sum(start_prob[l] * emm_prob[l][observations[0]] * b_curr[l] for l in states)

    # merging the two parts
    posterior = []
    for i in range(len(observations)):
        posterior.append({st: fwd[i][st] * bkw[i][st] / p_fwd for st in states})

    assert p_fwd == p_bkw
    return fwd, bkw, posterior
